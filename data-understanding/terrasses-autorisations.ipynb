# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("../data/terrasses-autorisations.csv", sep=";")

# %%
df.head(10)
# Out:
#           typologie                        adresse  arrondissement  \
# 0  TERRASSE OUVERTE            31BIS RUE NATIONALE         75013.0
# 1  TERRASSE OUVERTE               4 RUE DE LONDRES         75009.0
# 2           ETALAGE           113 BOULEVARD DAVOUT         75020.0
# 3   TERRASSE FERMÉE             79 AVENUE DE SEGUR         75015.0
# 4  TERRASSE OUVERTE     97 RUE DE L AMIRAL MOUCHEZ         75013.0
# 5  TERRASSE OUVERTE           300 RUE DES PYRENEES         75020.0
# 6   TERRASSE FERMÉE             2 RUE DE CRONSTADT         75015.0
# 7  TERRASSE OUVERTE  8 AVENUE FRANKLIN D ROOSEVELT         75008.0
# 8   PLANCHER MOBILE           10 RUE SAINT ANTOINE         75016.0
# 9  TERRASSE OUVERTE                48 RUE D ARGOUT         75002.0
#
#             nom_enseigne nom_societe         siret  longueur  largeur  \
# 0          PHO INDOCHINE         NaN  9.199596e+13      3.00     0.90
# 1               WHATEVER         NaN  4.390775e+13      8.70     0.90
# ...

# %%
df.tail(10)
# Out:
#                                                typologie  \
# 24197         CONTRE TERRASSE ESTIVALE SUR STATIONNEMENT
# 24198  CONTRE TERRASSE ESTIVALE SUR TROTTOIR FACE À L...
# 24199                    TERRASSES OUVERTES SUR TROTTOIR
# 24200                    TERRASSES OUVERTES SUR TROTTOIR
# 24201         CONTRE TERRASSE ESTIVALE SUR STATIONNEMENT
# 24202                    TERRASSES OUVERTES SUR TROTTOIR
# 24203                    TERRASSES OUVERTES SUR TROTTOIR
# 24204         CONTRE TERRASSE ESTIVALE SUR STATIONNEMENT
# 24205                    TERRASSES OUVERTES SUR TROTTOIR
# 24206  TERRASSE ESTIVALE SUR TROTTOIR FACE À LA DEVAN...
#
#                                  adresse  arrondissement        nom_enseigne  \
# 24197                   36 RUE D'AUTEUIL         75016.0             GINETTE
# 24198                2 PLACE DU CHATELET         75004.0  LE SARAH BERNHARDT
# 24199  307 RUE DU FAUBOURG SAINT ANTOINE         75011.0      EXTRA OLD CAFE
# ...

# %%
df.shape
# Out:
# (24207, 12)

# %%
df.value_counts
# Out:
# <bound method DataFrame.value_counts of                                                typologie  \
# 0                                       TERRASSE OUVERTE
# 1                                       TERRASSE OUVERTE
# 2                                                ETALAGE
# 3                                        TERRASSE FERMÉE
# 4                                       TERRASSE OUVERTE
# ...                                                  ...
# 24202                    TERRASSES OUVERTES SUR TROTTOIR
# 24203                    TERRASSES OUVERTES SUR TROTTOIR
# 24204         CONTRE TERRASSE ESTIVALE SUR STATIONNEMENT
# 24205                    TERRASSES OUVERTES SUR TROTTOIR
# 24206  TERRASSE ESTIVALE SUR TROTTOIR FACE À LA DEVAN...
#
#                             adresse  arrondissement      nom_enseigne  \
# 0               31BIS RUE NATIONALE         75013.0     PHO INDOCHINE
# 1                  4 RUE DE LONDRES         75009.0          WHATEVER
# ...

# %%
df.isnull().sum()
# Out:
# typologie                  10
# adresse                     8
# arrondissement            848
# nom_enseigne              737
# nom_societe             23473
# siret                     924
# longueur                   16
# largeur                    15
# periode_installation    23482
# lien_affichette          5443
# geo_shape                   0
# geo_point_2d                0
# dtype: int64

# %%
df.columns
# Out:
# Index(['typologie', 'adresse', 'arrondissement', 'nom_enseigne', 'nom_societe',
#        'siret', 'longueur', 'largeur', 'periode_installation',
#        'lien_affichette', 'geo_shape', 'geo_point_2d'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 24207 entries, 0 to 24206
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   typologie             24197 non-null  str
#  1   adresse               24199 non-null  str
#  2   arrondissement        23359 non-null  float64
#  3   nom_enseigne          23470 non-null  str
#  4   nom_societe           734 non-null    str
#  5   siret                 23283 non-null  float64
#  6   longueur              24191 non-null  float64
#  7   largeur               24192 non-null  float64
#  8   periode_installation  725 non-null    str
#  9   lien_affichette       18764 non-null  str
#  10  geo_shape             24207 non-null  str
#  11  geo_point_2d          24207 non-null  str
# dtypes: float64(4), str(8)
# memory usage: 2.2 MB

# %%
df.dtypes
# Out:
# typologie                   str
# adresse                     str
# arrondissement          float64
# nom_enseigne                str
# nom_societe                 str
# siret                   float64
# longueur                float64
# largeur                 float64
# periode_installation        str
# lien_affichette             str
# geo_shape                   str
# geo_point_2d                str
# dtype: object

# %%
df['arrondissement'].dtypes
# Out:
# dtype('float64')

# %%
df['arrondissement'].unique
# Out:
# <bound method Series.unique of 0        75013.0
# 1        75009.0
# 2        75020.0
# 3        75015.0
# 4        75013.0
#           ...
# 24202    75116.0
# 24203    75015.0
# 24204        NaN
# 24205    75001.0
# 24206    75007.0
# Name: arrondissement, Length: 24207, dtype: float64>

# %%
df['typologie'].unique
# Out:
# <bound method Series.unique of 0                                         TERRASSE OUVERTE
# 1                                         TERRASSE OUVERTE
# 2                                                  ETALAGE
# 3                                          TERRASSE FERMÉE
# 4                                         TERRASSE OUVERTE
#                                ...
# 24202                      TERRASSES OUVERTES SUR TROTTOIR
# 24203                      TERRASSES OUVERTES SUR TROTTOIR
# 24204           CONTRE TERRASSE ESTIVALE SUR STATIONNEMENT
# 24205                      TERRASSES OUVERTES SUR TROTTOIR
# 24206    TERRASSE ESTIVALE SUR TROTTOIR FACE À LA DEVAN...
# Name: typologie, Length: 24207, dtype: str>

# %%
df['arrondissement'].value_counts().unique
# Out:
# <bound method Series.unique of arrondissement
# 75015.0    1713
# 75010.0    1682
# 75011.0    1554
# 75017.0    1546
# 75018.0    1509
# 75012.0    1385
# 75009.0    1351
# 75014.0    1296
# 75005.0    1275
# 75020.0    1180
# 75008.0    1180
# 75013.0    1063
# 75019.0     904
# 75004.0     890
# 75001.0     847
# 75006.0     761
# 75007.0     696
# 75002.0     672
# 75016.0     653
# 75116.0     634
# 75003.0     568
# Name: count, dtype: int64>

# %%
df['adresse'].value_counts().unique
# Out:
# <bound method Series.unique of adresse
# 161 QUAI DE VALMY                15
# 3 RUE GEORGES PICQUART           11
# 4 PLACE TATTEGRAIN               11
# 108 BOULEVARD DU MONTPARNASSE    10
# 1 RUE CHAPTAL                    10
#                                  ..
# 20 RUE DE LA REYNIE               1
# 116 RUE DU CHEMIN VERT            1
# 46 AVENUE EMILE ZOLA              1
# 36 RUE D'AUTEUIL                  1
# 117 AVENUE DE LA BOURDONNAIS      1
# Name: count, Length: 14982, dtype: int64>

# %%
df['adresse'].isnull().sum()
# Out:
# np.int64(0)

# %%
df = df.dropna(subset=['adresse'])
