# %%
import pandas as pd
import numpy as np

# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-3.0.5-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.5.2-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached tzdata-2026.3-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-3.0.5-cp312-cp312-win_amd64.whl (9.8 MB)
# Using cached numpy-2.5.2-cp312-cp312-win_amd64.whl (12.5 MB)
# Using cached tzdata-2026.3-py2.py3-none-any.whl (348 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df= pd.read_csv("../data/dans-ma-rue.csv", sep=";")

# %%
df.head(10)
# Out:
#    numero                                        type  \
# 0   89946                           Objets abandonnés
# 1   46828   Graffitis, tags, affiches et autocollants
# 2   98544                           Objets abandonnés
# 3  150481                                    Propreté
# 4  155897  Activités commerciales et professionnelles
# 5    5802   Graffitis, tags, affiches et autocollants
# 6   20562   Graffitis, tags, affiches et autocollants
# 7   37776   Graffitis, tags, affiches et autocollants
# 8  144520                           Mobiliers urbains
# 9    6520                           Objets abandonnés
#
#                                             soustype  \
# 0               Autres objets encombrants abandonnés
# 1  Graffitis et autocollants sur mur, façade sur ...
# 2               Autres objets encombrants abandonnés
# 3  Propreté des équipements de collecte des déche...
# 4  Étalages et terrasses à usage commercial : Ter...
# ...

# %%
df.shape
# Out:
# (1474285, 17)

# %%
df.columns
# Out:
# Index(['numero', 'type', 'soustype', 'adresse', 'code_postal', 'ville',
#        'arrondissement', 'conseilquartier', 'datedecl', 'anneedecl',
#        'moisdecl', 'prefixe', 'intervenant', 'id_dmr', 'geo_shape',
#        'geo_point_2d', 'mois_annee_decla'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1474285 entries, 0 to 1474284
# Data columns (total 17 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   numero            1474285 non-null  int64
#  1   type              1474285 non-null  str
#  2   soustype          1474281 non-null  str
#  3   adresse           1474285 non-null  str
#  4   code_postal       1474282 non-null  float64
#  5   ville             1474285 non-null  str
#  6   arrondissement    1474285 non-null  int64
#  7   conseilquartier   1474174 non-null  str
#  8   datedecl          1474285 non-null  str
#  9   anneedecl         1474285 non-null  int64
#  10  moisdecl          1474285 non-null  int64
#  11  prefixe           1474285 non-null  str
#  12  intervenant       1474283 non-null  str
#  13  id_dmr            1474285 non-null  str
#  14  geo_shape         1474285 non-null  str
#  15  geo_point_2d      1474285 non-null  str
# ...

# %%
df.dtypes
# Out:
# numero                int64
# type                    str
# soustype                str
# adresse                 str
# code_postal         float64
# ville                   str
# arrondissement        int64
# conseilquartier         str
# datedecl                str
# anneedecl             int64
# moisdecl              int64
# prefixe                 str
# intervenant             str
# id_dmr                  str
# geo_shape               str
# geo_point_2d            str
# mois_annee_decla        str
# dtype: object

# %%
df.isnull().sum()
# Out:
# numero                0
# type                  0
# soustype              4
# adresse               0
# code_postal           3
# ville                 0
# arrondissement        0
# conseilquartier     111
# datedecl              0
# anneedecl             0
# moisdecl              0
# prefixe               0
# intervenant           2
# id_dmr                0
# geo_shape             0
# geo_point_2d          0
# mois_annee_decla      0
# dtype: int64

# %%
df.value_counts()
# Out:
# numero  type                                        soustype                                                                            adresse                                     code_postal  ville     arrondissement  conseilquartier              datedecl    anneedecl  moisdecl  prefixe            intervenant     id_dmr        geo_shape                                                                   geo_point_2d                            mois_annee_decla
# 89946   Objets abandonnés                           Autres objets encombrants abandonnés                                                16 rue Victor Duruy, 75015 PARIS            75015.0      Paris 15  15              ALLERAY - PROCESSION         2025-06-16  2025       6         Page DMR Paris.fr  DPE-STPP-DT     S2025F089946  {"coordinates": [2.2988817998435738, 48.837089999362114], "type": "Point"}  48.837089999362114, 2.2988817998435738  2025-06             1
# ...

# %%
df.mode()
# Out:
#          numero               type                              soustype  \
# 0         125.0  Objets abandonnés  Autres objets encombrants abandonnés
# 1         153.0                NaN                                   NaN
# 2         154.0                NaN                                   NaN
# 3         160.0                NaN                                   NaN
# 4         163.0                NaN                                   NaN
# ...         ...                ...                                   ...
# 1474280     NaN                NaN                                   NaN
# 1474281     NaN                NaN                                   NaN
# 1474282     NaN                NaN                                   NaN
# 1474283     NaN                NaN                                   NaN
# 1474284     NaN                NaN                                   NaN
#
#                                                    adresse  code_postal  \
# ...

# %%
df.value_counts().max()
# Out:
# np.int64(1)

# %%
# Affiche uniquement le nombre maximal de répétitions pour chaque colonne
df.apply(lambda x: x.value_counts().max())
# Out:
# numero                   17
# type                 631217
# soustype             496733
# adresse                 835
# code_postal          133051
# ville                132190
# arrondissement       132190
# conseilquartier       35088
# datedecl               4412
# anneedecl           1060484
# moisdecl             193549
# prefixe              893415
# intervenant          883737
# id_dmr                    1
# geo_shape               320
# geo_point_2d            320
# mois_annee_decla      97378
# dtype: int64

# %%
df['ville'].value_counts()
# Out:
# ville
# Paris 18    132190
# Paris 20    131858
# Paris 17    125147
# Paris 15    121025
# Paris 19    113396
# Paris 11    112121
# Paris 10    105243
# Paris 12     88825
# Paris 13     80375
# Paris 16     76525
# Paris 14     64846
# Paris 09     61152
# Paris 03     52893
# Paris 04     46020
# Paris 08     37317
# Paris 05     32249
# Paris 02     24986
# Paris 01     23680
# Paris 07     22705
# Paris 06     21623
# Paris 00       102
# Paris 82         4
# Paris 44         3
# Name: count, dtype: int64

# %%
df['arrondissement'].dtypes
# Out:
# dtype('int64')

# %%
df['arrondissement'].unique
# Out:
# <bound method Series.unique of 0          15
# 1          14
# 2          18
# 3          19
# 4          10
#            ..
# 1474280    11
# 1474281    13
# 1474282    11
# 1474283    15
# 1474284    13
# Name: arrondissement, Length: 1474285, dtype: int64>

# %%
df['arrondissement'].sample
# Out:
# <bound method NDFrame.sample of 0          15
# 1          14
# 2          18
# 3          19
# 4          10
#            ..
# 1474280    11
# 1474281    13
# 1474282    11
# 1474283    15
# 1474284    13
# Name: arrondissement, Length: 1474285, dtype: int64>

# %%
df['arrondissement'].value_counts().unique
# Out:
# <bound method Series.unique of arrondissement
# 18    132190
# 20    131858
# 17    125147
# 15    121025
# 19    113396
# 11    112121
# 10    105243
# 12     88825
# 13     80375
# 16     76525
# 14     64846
# 9      61152
# 3      52893
# 4      46020
# 8      37317
# 5      32249
# 2      24986
# 1      23680
# 7      22705
# 6      21623
# 0        102
# 82         4
# 44         3
# Name: count, dtype: int64>

# %%
df['adresse'].value_counts().unique
# Out:
# <bound method Series.unique of adresse
# Bois de Vincennes Route de la Pyramide, 75012 PARIS    835
# 2 Rue Pavée, 75004 PARIS                               413
# 21 Rue Pavée, 75004 PARIS                              374
# 13 Rue des Amiraux, 75018 PARIS                        354
# 2 Rue des Quatre-Fils, 75003 PARIS                     330
#                                                       ...
# 172  Avenue d'Italie, 75013 PARIS                        1
# 25 rue du Colonel Moll, 75017 PARIS                      1
# 75b rue des Entrepreneurs, 75015 PARIS                   1
# 68 Rue des Belles Feuilles, 75016 PARIS                  1
# 184 avenue Victor Hugo, 75116 PARIS                      1
# Name: count, Length: 207878, dtype: int64>

# %%
df['adresse'].isnull()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1474280    False
# 1474281    False
# 1474282    False
# 1474283    False
# 1474284    False
# Name: adresse, Length: 1474285, dtype: bool

# %%
df['adresse'].isnull().sum()
# Out:
# np.int64(0)
